# %% [markdown]
# # Gesture Recognition - Rohit Bhalerao and Naagaraj Subramanya FINAL
#
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
import numpy as np
import os
from scipy.misc import imread, imresize
import datetime
import os
import warnings
warnings.filterwarnings("ignore")
import abc
from sys import getsizeof
import cv2
import matplotlib.pyplot as plt
% matplotlib inline

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
tf.set_random_seed(30)

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
train_doc = np.random.permutation(open('./Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('./Project_data/val.csv').readlines())
batch_size = 10 #experiment with the batch size

# %%
# Define function to plot the model

def plot(history):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))
    axes[0].plot(history.history['loss'])   
    axes[0].plot(history.history['val_loss'])
    axes[0].legend(['loss','val_loss'])

    axes[1].plot(history.history['categorical_accuracy'])   
    axes[1].plot(history.history['val_categorical_accuracy'])
    axes[1].legend(['categorical_accuracy','val_categorical_accuracy'])

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
# Initialization of Parameters 

# number_of_rows = 120   # Rows : X dimension of the image : Model 1 and 2 config
# number_of_cols = 120   # Columns : Y dimesnion of the image : : Model 1 and 2 config


number_of_rows = 80   # Rows : X dimension of the image : : Model 2 config
number_of_cols = 80   # Columns : Y dimesnion of the image : : Model 2 config
number_of_frames = 30  # Images (Frames) per video
number_of_channels = 3 # Number of channels in images. Images are coloured images and so, it's 3 - BRG

# %%
# Supporting function toget a random affine transform on the iamge
def get_random_affine():
    dx, dy = np.random.randint(-1.7, 1.8, 2)
    M = np.float32([[1, 0, dx], [0, 1, dy]])
    return M

# %%
# Supporting function to initialize all the batch images data and labels
def init_batch_data(batch_size):
    batch_data = np.zeros((batch_size, number_of_frames, number_of_rows, number_of_cols, number_of_channels)) 
    batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output. There are 5 gestures 
    return batch_data, batch_labels

# %%
def load_batch_images(source_path, folder_list, batch_num, batch_size, t, validation):
    
    batch_data,batch_labels = init_batch_data(batch_size)
    
    # Building an augumented batch data for affine transformation
    batch_data_aug,batch_labels_aug = init_batch_data(batch_size)
    
    # Building a batch data for horizontal flip    
    # batch_data_flip,batch_labels_flip = init_batch_data(batch_size)
    
    # Create a list of image numbers to be used for a particular video using full frames. Here number of frames is 30
    img_idx = [x for x in range(0, number_of_frames)]

    for folder in range(batch_size): # iterate over the batch_size
        # reading all the images in the folder
        imgs = sorted(os.listdir(source_path+'/'+ t[folder + (batch_num*batch_size)].split(';')[0]))
        
        # Generating a random affine to be used in image transformation for buidling agumented data set
        M = get_random_affine()
        
        #  Iterate over the images of a folder to read them
        
        for idx, item in enumerate(img_idx): 
            image = cv2.imread(source_path+'/'+ t[folder + (batch_num*batch_size)].strip().split(';')[0]+'/'+imgs[item], cv2.IMREAD_COLOR)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            
            # Normlalize the image to reduce any noise
            
            image = (image - np.min(image)) / (np.max(image) - np.min(image)) # model  3 
            
            
            # Crop non symmetric frames 120 x 160 into 120 x 120 pixels
            
            if image.shape[0] != image.shape[1]:
                image=image[0:120,20:140]
            
            # resize the images as images are of 2 different shapes ( 360x360 and 120x160) 
            # conv3D will give error if the images in a batch have different shapes   

            resized = cv2.resize(image, (120,120), interpolation = cv2.INTER_AREA)

            # Crop the images as images to get center portion of 80 pixels
            # Mode 3 config
            cropped=resized[20:100,20:100]

            # Normal data
            batch_data[folder,idx] = (cropped) # Model 3 Config to crop images to 80 x 80
            
            # Data with affine transformation
            # batch_data_aug[folder,idx] = (cv2.warpAffine(resized, M, (resized.shape[0], resized.shape[1]))) # Model 1 and 2

            batch_data_aug[folder,idx] = (cv2.warpAffine(cropped, M, (cropped.shape[0], cropped.shape[1]))) # Model 3
            
            

        batch_labels[folder, int(t[folder + (batch_num*batch_size)].strip().split(';')[2])] = 1
        batch_labels_aug[folder, int(t[folder + (batch_num*batch_size)].strip().split(';')[2])] = 1
        
                  
    # Create Final batch data and labels 
    
    batch_data_final = np.append(batch_data, batch_data_aug, axis = 0)
    batch_labels_final = np.append(batch_labels, batch_labels_aug, axis = 0) 

 
    if validation:
        batch_data_final=batch_data
        batch_labels_final= batch_labels
        
    return batch_data_final,batch_labels_final

# %%
def generator(source_path, folder_list, batch_size, validation=False):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(folder_list)//batch_size # here, number of batches is calculated
        
        for batch in range(num_batches): # we iterate over the number of batches
            # you yield the batch_data and the batch_labels, remember what does yield do
            yield load_batch_images(source_path, folder_list, batch, batch_size, t,validation)
            
        # Code for the remaining data points which are left after full batches
        if (len(folder_list) != batch_size*num_batches):
            batch_size = len(folder_list) - (batch_size*num_batches)
            yield load_batch_images(source_path, folder_list, batch, batch_size, t,validation)

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = './Project_data/train'
val_path = './Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 10 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 10

# %% [markdown]
# ## Model - 3D convolution model and MaxPooling3D
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %% [markdown]
# ## Model 1 : Parameters
#
# ### 4 x Conv3D layers with 64 filters each
# ### nb_filters for Conv# D layers = [8,8,8,8]
# ### nb_dense = [256, 128, 5]
# ### Kernel size : 3,3,3 for all Conv3D layers
# ### No dropouts at Conv3D or Dense layers

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout
from keras.layers.convolutional import Conv3D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.losses import categorical_crossentropy
from keras import optimizers
from keras.optimizers import Adam


#write your model here
nb_filters = [8,8,8,8]
nb_dense = [256, 128, 5]

# Input shape. This will depend on number of frames, image dimensions and channels
input_shape=(number_of_frames, number_of_rows, number_of_cols, number_of_channels)

# Define model
model = Sequential()

model.add(Conv3D(nb_filters[0],kernel_size=(3,3,3),input_shape=input_shape,padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))


model.add(Conv3D(nb_filters[1],kernel_size=(3,3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))


model.add(Conv3D(nb_filters[2],kernel_size=(3,3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(nb_filters[3],kernel_size=(3,3,3),padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

#Flatten Layers
model.add(Flatten())
model.add(Dense(nb_dense[0], activation='relu'))
model.add(Dense(nb_dense[1], activation='relu'))

#softmax layer
model.add(Dense(nb_dense[2], activation='softmax'))

# %%
optimiser = Adam() #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv3d_17 (Conv3D)           (None, 30, 120, 120, 8)   656
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 30, 120, 120, 8)   32
# _________________________________________________________________
# activation_17 (Activation)   (None, 30, 120, 120, 8)   0
# _________________________________________________________________
# max_pooling3d_17 (MaxPooling (None, 15, 60, 60, 8)     0
# _________________________________________________________________
# conv3d_18 (Conv3D)           (None, 15, 60, 60, 8)     1736
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 15, 60, 60, 8)     32
# _________________________________________________________________
# activation_18 (Activation)   (None, 15, 60, 60, 8)     0
# ...

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
num_epochs = 20

m1 = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  ./Project_data/val ; batch size = 10
# Source path =  ./Project_data/train ; batch size = 10
# Epoch 1/20
# 67/67 [==============================] - 21s 309ms/step - loss: 1.4514 - categorical_accuracy: 0.3483 - val_loss: 1.5731 - val_categorical_accuracy: 0.2550
#
# Epoch 00002: saving model to model_init_2020-09-1816_59_59.660099/model-00002-1.45142-0.34826-1.57307-0.25500.h5
# Epoch 3/20
# 67/67 [==============================] - 21s 307ms/step - loss: 1.4699 - categorical_accuracy: 0.3109 - val_loss: 1.3967 - val_categorical_accuracy: 0.3500
#
# Epoch 00003: saving model to model_init_2020-09-1816_59_59.660099/model-00003-1.46994-0.31095-1.39667-0.35000.h5
# Epoch 4/20
# 67/67 [==============================] - 20s 295ms/step - loss: 1.3361 - categorical_accuracy: 0.3706 - val_loss: 1.4169 - val_categorical_accuracy: 0.3600
#
# Epoch 00004: saving model to model_init_2020-09-1816_59_59.660099/model-00004-1.33608-0.37065-1.41686-0.36000.h5
# Epoch 5/20
# ...

# %%
plot(m1)

# %% [markdown]
# # Model  #2 :
#
# ## Parameters
#
# ### 4 x Conv3D layers with filters size [8,16,32,64]
# ### nb_dense : Number of neurons = [256, 128, 5]
# ### Kernel size : 3,3,3 for first 2 Conv3D layers and 2,2,2 for last 2 Conv3D layers
# ### No dropouts at Conv3D or Dense layers

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout
from keras.layers.convolutional import Conv3D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.losses import categorical_crossentropy
from keras import optimizers
from keras.optimizers import Adam


#write your model here
nb_filters = [8,16,32,64]
nb_dense = [256, 128, 5]

# Input shape. This will depend on number of frames, image dimensions and channels
input_shape=(number_of_frames, number_of_rows, number_of_cols, number_of_channels)

# Define model
model = Sequential()

model.add(Conv3D(nb_filters[0],kernel_size=(3,3,3),input_shape=input_shape,padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))


model.add(Conv3D(nb_filters[1],kernel_size=(3,3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))


model.add(Conv3D(nb_filters[2],kernel_size=(2,2,2),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(nb_filters[3],kernel_size=(2,2,2),padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

#Flatten Layers
model.add(Flatten())
model.add(Dense(nb_dense[0], activation='relu'))
model.add(Dense(nb_dense[1], activation='relu'))

#softmax layer
model.add(Dense(nb_dense[2], activation='softmax'))

# %%
optimiser = Adam() #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv3d_33 (Conv3D)           (None, 30, 120, 120, 8)   656
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 30, 120, 120, 8)   32
# _________________________________________________________________
# activation_33 (Activation)   (None, 30, 120, 120, 8)   0
# _________________________________________________________________
# max_pooling3d_33 (MaxPooling (None, 15, 60, 60, 8)     0
# _________________________________________________________________
# conv3d_34 (Conv3D)           (None, 15, 60, 60, 16)    3472
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 15, 60, 60, 16)    64
# _________________________________________________________________
# activation_34 (Activation)   (None, 15, 60, 60, 16)    0
# ...

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
num_epochs = 20

m1 = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  ./Project_data/val ; batch size = 10
# Source path =  ./Project_data/train ; batch size = 10
# Epoch 1/20
# 67/67 [==============================] - 65s 975ms/step - loss: 1.6347 - categorical_accuracy: 0.2443 - val_loss: 1.5609 - val_categorical_accuracy: 0.2550
#
# Epoch 00001: saving model to model_init_2020-09-1816_59_59.660099/model-00001-1.63455-0.24510-1.56091-0.25500.h5
# Epoch 2/20
# 67/67 [==============================] - 20s 297ms/step - loss: 1.4160 - categorical_accuracy: 0.3507 - val_loss: 1.9827 - val_categorical_accuracy: 0.1950
#
# Epoch 00002: saving model to model_init_2020-09-1816_59_59.660099/model-00002-1.41596-0.35075-1.98272-0.19500.h5
# Epoch 3/20
# 67/67 [==============================] - 20s 304ms/step - loss: 1.3898 - categorical_accuracy: 0.3607 - val_loss: 1.4484 - val_categorical_accuracy: 0.3100
#
# Epoch 00003: saving model to model_init_2020-09-1816_59_59.660099/model-00003-1.38982-0.36070-1.44838-0.31000.h5
# Epoch 4/20
# ...

# %%
plot(m1)

# %% [markdown]
# # Model  #3 :
#
# ## Parameters
#
# ### 4 x Conv3D layers with filters size [8,16,32,64]
# ### nb_dense : Number of neurons = [256, 128, 5]
# ### Kernel size : 3,3,3 for first 2 Conv3D layers and 2,2,2 for last 2 Conv3D layers
# ### No dropouts at Conv3D or Dense layers
#
# ### Image processing to be improved.
# ### Image normalization to be tried to reduce the noise. Also, image size 80x80 to be considered with each 120x120 image cropped to get maximum relevant portion of the image ( cut down the noise)

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout
from keras.layers.convolutional import Conv3D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.losses import categorical_crossentropy
from keras import optimizers
from keras.optimizers import Adam


#write your model here
nb_filters = [8,16,32,64]
nb_dense = [256, 128, 5]

# Input shape. This will depend on number of frames, image dimensions and channels
input_shape=(number_of_frames, number_of_rows, number_of_cols, number_of_channels)

# Define model
model = Sequential()

model.add(Conv3D(nb_filters[0],kernel_size=(3,3,3),input_shape=input_shape,padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))


model.add(Conv3D(nb_filters[1],kernel_size=(3,3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))


model.add(Conv3D(nb_filters[2],kernel_size=(2,2,2),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(nb_filters[3],kernel_size=(2,2,2),padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

#Flatten Layers
model.add(Flatten())
model.add(Dense(nb_dense[0], activation='relu'))
model.add(Dense(nb_dense[1], activation='relu'))

#softmax layer
model.add(Dense(nb_dense[2], activation='softmax'))

# %%
optimiser = Adam() #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv3d_37 (Conv3D)           (None, 30, 80, 80, 8)     656
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 30, 80, 80, 8)     32
# _________________________________________________________________
# activation_37 (Activation)   (None, 30, 80, 80, 8)     0
# _________________________________________________________________
# max_pooling3d_37 (MaxPooling (None, 15, 40, 40, 8)     0
# _________________________________________________________________
# conv3d_38 (Conv3D)           (None, 15, 40, 40, 16)    3472
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 15, 40, 40, 16)    64
# _________________________________________________________________
# activation_38 (Activation)   (None, 15, 40, 40, 16)    0
# ...

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
num_epochs = 20

m1 = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  ./Project_data/val ; batch size = 10
# Source path =  ./Project_data/train ; batch size = 10
# Epoch 1/20
# 67/67 [==============================] - 65s 977ms/step - loss: 1.4523 - categorical_accuracy: 0.3530 - val_loss: 0.9913 - val_categorical_accuracy: 0.5400
#
# Epoch 00001: saving model to model_init_2020-09-1817_42_35.003752/model-00001-1.44678-0.35671-0.99127-0.54000.h5
# Epoch 2/20
# 67/67 [==============================] - 17s 257ms/step - loss: 1.1139 - categorical_accuracy: 0.5498 - val_loss: 1.0990 - val_categorical_accuracy: 0.5600
#
# Epoch 00002: saving model to model_init_2020-09-1817_42_35.003752/model-00002-1.11386-0.54975-1.09899-0.56000.h5
# Epoch 3/20
# 67/67 [==============================] - 20s 292ms/step - loss: 1.1346 - categorical_accuracy: 0.5572 - val_loss: 0.9316 - val_categorical_accuracy: 0.6050
#
# Epoch 00003: saving model to model_init_2020-09-1817_42_35.003752/model-00003-1.13456-0.55721-0.93160-0.60500.h5
# Epoch 4/20
# ...

# %%
plot(m1)

# %% [markdown]
# # Model  #4 :
#
# ## Parameters
#
# ### 4 x Conv3D layers with filters size [8,16,32,64]
# ### nb_dense : Number of neurons = [256, 128, 5]
# ### Kernel size : 3,3,3 for first 2 Conv3D layers and 2,2,2 for last 2 Conv3D layers
#
# ### Image processing improved.
# ### Image normalization to be tried to reduce the noise. Also, image size 80x80 to be considered with each 120x120 image cropped to get maximum relevant portion of the image ( cut down the noise)
#
# ### Dropouts at last Conv3D or Dense layers

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout
from keras.layers.convolutional import Conv3D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.losses import categorical_crossentropy
from keras import optimizers
from keras.optimizers import Adam


#write your model here
nb_filters = [8,16,32,64]
nb_dense = [256, 128, 5]

# Input shape. This will depend on number of frames, image dimensions and channels
input_shape=(number_of_frames, number_of_rows, number_of_cols, number_of_channels)

# Define model
model = Sequential()

model.add(Conv3D(nb_filters[0],kernel_size=(3,3,3),input_shape=input_shape,padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))


model.add(Conv3D(nb_filters[1],kernel_size=(3,3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))


model.add(Conv3D(nb_filters[2],kernel_size=(2,2,2),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(nb_filters[3],kernel_size=(2,2,2),padding='same'))
model.add(Activation('relu'))
model.add(Dropout(0.25))
model.add(MaxPooling3D(pool_size=(2,2,2)))

#Flatten Layers
model.add(Flatten())
model.add(Dense(nb_dense[0], activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(nb_dense[1], activation='relu'))
model.add(Dropout(0.5))

#softmax layer
model.add(Dense(nb_dense[2], activation='softmax'))

# %%
optimiser = Adam() #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv3d_45 (Conv3D)           (None, 30, 80, 80, 8)     656
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 30, 80, 80, 8)     32
# _________________________________________________________________
# activation_45 (Activation)   (None, 30, 80, 80, 8)     0
# _________________________________________________________________
# max_pooling3d_45 (MaxPooling (None, 15, 40, 40, 8)     0
# _________________________________________________________________
# conv3d_46 (Conv3D)           (None, 15, 40, 40, 16)    3472
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 15, 40, 40, 16)    64
# _________________________________________________________________
# activation_46 (Activation)   (None, 15, 40, 40, 16)    0
# ...

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
num_epochs = 20

m1 = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path = Source path =  ./Project_data/train  ./Project_data/val ; batch size = 10
# ; batch size = 10
# Epoch 1/20
# 67/67 [==============================] - 65s 971ms/step - loss: 1.7246 - categorical_accuracy: 0.3080 - val_loss: 2.3081 - val_categorical_accuracy: 0.2300
#
# Epoch 00001: saving model to model_init_2020-09-1817_42_35.003752/model-00001-1.73042-0.30769-2.30809-0.23000.h5
# Epoch 2/20
# 67/67 [==============================] - 18s 272ms/step - loss: 1.4216 - categorical_accuracy: 0.3881 - val_loss: 2.8580 - val_categorical_accuracy: 0.2300
#
# Epoch 00002: saving model to model_init_2020-09-1817_42_35.003752/model-00002-1.42159-0.38806-2.85799-0.23000.h5
# Epoch 3/20
# 67/67 [==============================] - 17s 259ms/step - loss: 1.3717 - categorical_accuracy: 0.4204 - val_loss: 1.4547 - val_categorical_accuracy: 0.3300
#
# Epoch 00003: saving model to model_init_2020-09-1817_42_35.003752/model-00003-1.37170-0.42040-1.45471-0.33000.h5
# Epoch 4/20
# ...

# %%
plot(m1)

# %% [markdown]
# # Model  #5 : CONV2D + LSTM Model
#
# ## Parameters
#
# ### 4 x Conv2D layers with filters size [16,32,64,128]
# ###  Number of neuronsin dense layer  = 64
# ### LSTM Cells  :  64
#
# ### Kernel size : 3,3
#
# ### Image normalization to be tried to reduce the noise. Also, image size 80x80 to be considered with each 120x120 image cropped to get maximum relevant portion of the image ( cut down the noise)

# %%
from keras.layers.convolutional import Conv2D, MaxPooling2D

lstm_cells=64
dense_neurons=64
dropout=0.25


number_of_rows = 80   # Rows : X dimension of the image
number_of_cols = 80   # Columns : Y dimesnion of the image
number_of_frames = 30  # Images (Frames) per video
number_of_channels = 3 # Number of channels in images. Images are coloured images and so, it's 3 - BRG

model = Sequential()

model.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu'),input_shape=(number_of_frames,number_of_cols,number_of_rows,number_of_channels)))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
model.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
model.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
model.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))
model.add(TimeDistributed(MaxPooling2D((2, 2))))


model.add(TimeDistributed(Flatten()))


model.add(GRU(lstm_cells))
model.add(Dropout(dropout))
        
model.add(Dense(dense_neurons,activation='relu'))
model.add(Dropout(dropout))
        
model.add(Dense(5, activation='softmax'))
optimiser = optimizers.Adam(lr=0.0002)
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# time_distributed_40 (TimeDis (None, 30, 80, 80, 16)    448
# _________________________________________________________________
# time_distributed_41 (TimeDis (None, 30, 80, 80, 16)    64
# _________________________________________________________________
# time_distributed_42 (TimeDis (None, 30, 40, 40, 16)    0
# _________________________________________________________________
# time_distributed_43 (TimeDis (None, 30, 40, 40, 32)    4640
# _________________________________________________________________
# time_distributed_44 (TimeDis (None, 30, 40, 40, 32)    128
# _________________________________________________________________
# time_distributed_45 (TimeDis (None, 30, 20, 20, 32)    0
# _________________________________________________________________
# time_distributed_46 (TimeDis (None, 30, 20, 20, 64)    18496
# ...

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1) # write the REducelronplateau code here

callbacks_list = [checkpoint, LR]

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %%
num_epochs = 40

m1 = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/40
# 67/67 [==============================] - 19s 290ms/step - loss: 0.3425 - categorical_accuracy: 0.9030 - val_loss: 0.6936 - val_categorical_accuracy: 0.7800
#
# Epoch 00001: saving model to model_init_2020-09-1819_46_47.214967/model-00001-0.34247-0.90299-0.69364-0.78000.h5
# Epoch 2/40
# 67/67 [==============================] - 16s 246ms/step - loss: 0.3291 - categorical_accuracy: 0.9154 - val_loss: 0.6645 - val_categorical_accuracy: 0.7800
#
# Epoch 00002: saving model to model_init_2020-09-1819_46_47.214967/model-00002-0.32907-0.91542-0.66447-0.78000.h5
# Epoch 3/40
# 67/67 [==============================] - 16s 237ms/step - loss: 0.2989 - categorical_accuracy: 0.9204 - val_loss: 0.7269 - val_categorical_accuracy: 0.7350
#
# Epoch 00003: saving model to model_init_2020-09-1819_46_47.214967/model-00003-0.29889-0.92040-0.72685-0.73500.h5
# Epoch 4/40
# ...

# %%
plot(m1)
